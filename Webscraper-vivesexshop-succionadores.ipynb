# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36'
}

productlinks = []

for x in range(1,12):
    r = requests.get(f'https://www.vivesexshop.com/es/succionadores-de-clitoris?pagina={x}')
    soup = BeautifulSoup(r.content, 'lxml', from_encoding="utf-8")
    productlist = soup.find_all('div', class_='col-6 col-sm-4 contenedor-producto')
    for item in productlist:
        for link in item.find_all('a', href=True):
            productlinks.append(link['href'])

# %%
toy_list = []
for link in productlinks:
    r = requests.get(link, headers=headers)
    soup = BeautifulSoup(r.content, 'lxml')
    try:
        name = soup.find('h1').text.strip()
    except:
        name = 'No name'
     
    # cambiar codigo para Brands
    try:    
        brand = soup.find('div',class_='col-12 col-md-6 col-lg-5 paddingT20-xs nombre-producto flota-derecha').find('a').get('title')
        
    except:
        brand = 'No brand'
        
    try:    
        price = soup.find('span', class_='precio_web').text.strip()
    except:
        price = "No price"
    
    try:
        oldprice = soup.find('span', class_='precio-tachado').text.strip()
    except:
        oldprice='No old price'
        
    try:    
        ref = soup.find('span', id='referencia').text.strip()
    except:
        ref='No ref'
    
    try:
        rating = soup.find('a', class_='ancla-opiniones ancla-movimiento').text.strip()
    except:
        rating = 'no rating'
        
    url = link
        
    toys = {
        
        'name': name,
        'brand': brand,
        'reference': ref,
        'rating': rating,
        'actual price': price,
        'old price': oldprice,
        'url': url
        }

    toy_list.append(toys)
#     print(brand)
    print('Saved: ', toys['name'])
    
df = pd.DataFrame(toy_list)
df.to_csv('vivesexshop_succionadores.csv', index=False)
print('All saved!')
# Out:
# Saved:  Satisfyer Pro 2 Modelo 2020
# Saved:  Satisfyer Penguin
# Saved:  Satisfyer Number One
# Saved:  Satisfyer Pro 3
# Saved:  Satsifyer Pro G-spot Rabbit
# Saved:  Satisfyer Pro 4 Couples
# Saved:  Satisfyer Curvy 2+
# Saved:  Sqweel 2
# Saved:  Satisfyer Pro 2 Modelo 2020
# Saved:  Satisfyer Pro 3
# Saved:  Irresistible Desirable
# Saved:  Adrien Lastic Inspiration
# Saved:  Satisfyer Penguin
# Saved:  Irresistible Mythical
# Saved:  Irresistible Kissable
# Saved:  Womanizer Premium Eco
# Saved:  Satisfyer Number One
# Saved:  Satisfyer Curvy 2+
# Saved:  Satsifyer Pro G-spot Rabbit
# Saved:  Fabulous Four
# Saved:  Satisfyer Curvy 1+
# Saved:  Satisfyer 2
# Saved:  Satisfyer Pro 4 Couples
# Saved:  Masajeador De Clitoris
# Saved:  Nipple Suckers
# Saved:  Satisfyer Dual Love
# Saved:  Alive
# Saved:  Fetish Fantasy Succionador Vag
# Saved:  Lucky Libra
# Saved:  Satisfyer Love Breeze
# Saved:  Satisfyer Pro Traveler
# Saved:  Revo Bunny Magic G
# Saved:  Kit Fundas Satisfyer Pro 2
# Saved:  Satisfyer Love Triangle
# Saved:  Sqweel 2
# Saved:  Satisfyer Pro Plus Vibration
# Saved:  Kit Fundas Satisfyer Penguin
# Saved:  Lelo Sila Cruise
# Saved:  Satisfyer Dual Pleasure
# Saved:  Twitch Hands
# Saved:  Pussy Pump
# Saved:  Lelo Sona 2 Cruise
# Saved:  Kit De Fundas Satisfyer 2
# Saved:  Succionador
# Saved:  Irresistible Invencible
# Saved:  Satisfyer Luxury Pret-a Porter
# Saved:  Irresistible Seductive
# Saved:  Womanizer Premium
# Saved:  Lelo Sona 2 Sonic
# Saved:  Alkala
# Saved:  Destiny
# Saved:  Revo Cyclon
# Saved:  Womanizer duo
# Saved:  Womanizer Liberty
# Saved:  Womanizer classic
# Saved:  Womanizer liberty by lily alle
# Saved:  Womanizer Starlet 2
# Saved:  Womanizer golden moments
# Saved:  Jesse
# Saved:  Advanced Clitoral Pump
# Saved:  Vibrating Pussy Pump
# All saved!
